# %%
from splinter import Browser
#from selenium import webdriver
#from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup 
import requests
import time
import pandas as pd
import pprint
import webbrowser
import urllib
import re
from geopy.geocoders import Nominatim

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
#browser = Browser()

# %%
#search=input("What would you like to search")
#search=search.replace(" ","+")
#link="https://www.google.com/search?q="+search
#link = "https://www.google.com/maps/search/"+search
#print(link)
#source=requests.get(link).text

# %%
url = 'https://www.google.com/search?rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=05bdXaEyoqX9BoGbkuAK&q=kids+sports+classes+new+jersey&oq=kids+sports+classes+new+jersey&gs_l=psy-ab.12...13265.16654.0.22362.7.7.0.0.0.0.83.504.7.7.0....0...1c.1.64.psy-ab..0.0.0....0.EEUl6U13Yy0#rlfi=hd:;si:;mv:[[41.1122716,-73.93472659999999],[40.3136717,-74.6914486]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!2m1!1e3!3sIAE,lf:1,lf_ui:3'
#url = soup.find_("svg",focusable = {"false": "http://www.w3.org/2000/svg"})
browser.visit(url)

browser.find_by_name('btnG').first.click()

html = browser.html
soup = BeautifulSoup(html, 'html.parser')
time.sleep(5)

Data = soup.find_all("div",attrs = {"class": "VkpGBb"})

print(len(Data))
top_result = []
    
for tr in Data:
    dataframe = {}
    dataframe["Name"] = (tr.find("div",attrs = {"class": "dbg0pd"})).text.replace('\n', ' ')
    dataframe["Reviews"] = (tr.find('span', {'class':'BTtC6e'}))
    top_result.append(dataframe)
print(top_result)
# Out:
# 21
# [{'Name': 'Camp Pinebrook', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'New Jersey Kick Boxing', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'The GYM For Kids', 'Reviews': None}, {'Name': 'New York Sports Clubs', 'Reviews': None}, {'Name': 'My Gym Jersey City', 'Reviews': None}]

# %%
Data = []
geolocator = Nominatim()
geolocator = Nominatim()
pageData = soup.find_all(class_='std')
#print( soup.find("div", class_="std")["aria-label"] )

print(len(pageData))
for tr in pageData:
    
    pLink = str(tr.find('a')['href'])
    print(pLink)

top_result = []
list1 = [2, 4, 6,8,10,12] 
for x in (list1):
    prePage = x
    print(prePage)
    startPage = "start="+ str(prePage) +"0"
    print(startPage)
    replacePage = "start="+ str(prePage+2) +"0"
    print(replacePage)
    pLink = pLink.replace(startPage,replacePage)
    pageLink = "https://www.google.com" + pLink
    print(pageLink)
    browser.visit(pageLink)

  
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    Data = soup.find_all("div",attrs = {"class": "VkpGBb"})

    print(len(Data))
    
    for tr in Data:
        
        dataframe = {}
        dataframe["Name"] = (tr.find("div",attrs = {"class": "dbg0pd"})).text.replace('\n', ' ')
        dataframe["Reviews"] = (tr.find('span', {'class':'BTtC6e'}))
    
        PhoneData = tr.find('span').text.split(' ')
        print(PhoneData)
        lPhoneData = len(PhoneData)
        phoneNo = PhoneData[lPhoneData-2]+ PhoneData[lPhoneData-1]
        phoneNo = re.sub("\D", "", phoneNo)
        dataframe["phoneNo"] = phoneNo
        
        dirClass = (tr.find('div', {'class':'UbRuwe'}))
        #print(dirClass)
        if dirClass != None :
        #if hasattr('a', 'cursor:pointer'):
            rawAddress = (tr.find("a",attrs = {"class": "yYlJEf VByer"})["data-url"])
            
            orgAddress = rawAddress.split('/')[4].strip()
            print(orgAddress)
            orgAddress = orgAddress.replace('+',' ')
            orgAddress = orgAddress.split(',')
            
            print(orgAddress)
            lenAddress = len(orgAddress)
            
            if lenAddress == 4:
                ZipCode = orgAddress[3].split(' ')
                #print(ZipCode)
                #print (string_in_slashes.split(','))
            
                dataframe["Address"] = orgAddress[1]
                dataframe["City"] = orgAddress[2]
                dataframe["State"] = ZipCode[1]
                if len(ZipCode) > 2:
                    dataframe["Zipcode"] = ZipCode[2]
                    #dataframe["Zipcode"] = orgAddress[4]
                    
            if lenAddress > 4 :
                ZipCode = orgAddress[lenAddress-1].split(' ')
                print(ZipCode)
                #print (string_in_slashes.split(','))
            
                dataframe["Address"] = orgAddress[lenAddress-3]
                dataframe["City"] = orgAddress[lenAddress-2]
                dataframe["State"] = ZipCode[1]
                if len(ZipCode) > 2:
                    dataframe["Zipcode"] = ZipCode[2]
                    #dataframe["Zipcode"] = orgAddress[4]
            
                
            if lenAddress < 4 :
                ZipCode = orgAddress[lenAddress-1].split(' ')
                print(orgAddress)
                #print (string_in_slashes.split(','))
            
                dataframe["Address"] = orgAddress[lenAddress-2]
                dataframe["City"] = orgAddress[lenAddress-1]
                dataframe["State"] = ZipCode[1]
                if len(ZipCode) > 2:
                    dataframe["Zipcode"] = ZipCode[2]
                    #dataframe["Zipcode"] = orgAddress[4]
            
                print(orgAddress)
                    
            try:
                locForLatLong = dataframe["Address"] + dataframe["City"]
                print(locForLatLong)
                location = geolocator.geocode(locForLatLong, timeout=10)
                print(location.address)
                print((location.latitude,location.longitude))
                dataframe["Location"] = [location.latitude,location.longitude]
                
            except AttributeError:
                print('Cant Find the address')
                
        top_result.append(dataframe)

#print(top_result)
df=pd.DataFrame(top_result)
# Out:
# 1
# /search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=20&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# 2
# start=20
# start=40
# https://www.google.com/search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=40&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# C:\Users\13157\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#
# C:\Users\13157\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 20
# ['PreschoolMontclair,', 'NJ(973)', '826-0350Closed', '⋅', 'Opens', '9AM', 'Wed']
# Kidville,+516+Valley+Rd,+Montclair,+NJ+07043
# ['Kidville', ' 516 Valley Rd', ' Montclair', ' NJ 07043']
#  516 Valley Rd Montclair
# 516, Valley Road, Montclair, Essex County, New Jersey, 07043, United States of America
# (40.837221, -74.206941)
# ['Gymnastics', 'centerMatawan,', 'NJ(732)', '772-0060']
# The+Little+Gym+of+Aberdeen,+1121+NJ-34+Suite+O,+Matawan,+NJ+07747
# ['The Little Gym of Aberdeen', ' 1121 NJ-34 Suite O', ' Matawan', ' NJ 07747']
#  1121 NJ-34 Suite O Matawan
# Cant Find the address
# ['Martial', 'arts', 'schoolElizabeth,', 'NJ(908)', '354-0203Closed', '⋅', 'Opens', '4PM', 'Wed']
# Shim's+Martial+Arts+Academy,+1115+E+Jersey+St,+Elizabeth,+NJ+07201
# ["Shim's Martial Arts Academy", ' 1115 E Jersey St', ' Elizabeth', ' NJ 07201']
#  1115 E Jersey St Elizabeth
# 1115, East Jersey Street, Elizabeth, Union County, New Jersey, 07201, United States of America
# (40.6645016373729, -74.2119637176314)
# ['Dance', 'schoolJersey', 'City,', 'NJ(201)', '659-2190Closed', '⋅', 'Opens', '2PM', 'Wed']
# The+Kennedy+Dancers,+79+Central+Ave,+Jersey+City,+NJ+07306
# ['The Kennedy Dancers', ' 79 Central Ave', ' Jersey City', ' NJ 07306']
#  79 Central Ave Jersey City
# 79, Central Avenue, Jersey City, Hudson County, New Jersey, 07306, United States of America
# (40.737391, -74.055331)
# ['Karate', 'schoolBayonne,', 'NJ(201)', '339-4448Closed', '⋅', 'Opens', '3PM', 'Wed']
# Bayonne+Karate+For+Kids,+434+Broadway,+Bayonne,+NJ+07002
# ['Bayonne Karate For Kids', ' 434 Broadway', ' Bayonne', ' NJ 07002']
#  434 Broadway Bayonne
# 434, Broadway, Bayonne, Hudson County, New Jersey, 07002, United States of America
# (40.6617075, -74.1200142)
# ['Gymnastics', 'centerSummit,', 'NJ(908)', '608-9400']
# The+Little+Gym+of+Summit,+545+Morris+Ave,+Summit,+NJ+07901
# ['The Little Gym of Summit', ' 545 Morris Ave', ' Summit', ' NJ 07901']
#  545 Morris Ave Summit
# 545, Morris Avenue, Summit, Union County, New Jersey, 07901, United States of America
# (40.728246, -74.375629)
# ['GymMontclair,', 'NJClosed', '⋅', 'Opens', '3:30PM', 'Wed']
# Inclusive+Movement+Center,+198+Bellevue+Ave,+Montclair,+NJ+07043
# ['Inclusive Movement Center', ' 198 Bellevue Ave', ' Montclair', ' NJ 07043']
#  198 Bellevue Ave Montclair
# 198, Bellevue Avenue, Montclair, Essex County, New Jersey, 07043, United States
# (40.840584, -74.20581)
# ['Martial', 'arts', 'schoolJersey', 'City,', 'NJ(201)', '333-1006Closed', '⋅', 'Opens', '11AM', 'Wed']
# JC+Taekwondo+and+Kickboxing+Academy,+150+Newark+Ave,+Jersey+City,+NJ+07302
# ['JC Taekwondo and Kickboxing Academy', ' 150 Newark Ave', ' Jersey City', ' NJ 07302']
#  150 Newark Ave Jersey City
# Jersey City Taekwando and Kickboxing Academy, 150, Newark Avenue, Downtown Jersey City, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.720706, -74.0439375360249)
# ['Dance', 'schoolHoboken,', 'NJ(201)', '222-8033Closed', '⋅', 'Opens', '9AM', 'Wed']
# Monroe+Street+Movement+Space,+720+Monroe+St,+Hoboken,+NJ+07030
# ['Monroe Street Movement Space', ' 720 Monroe St', ' Hoboken', ' NJ 07030']
#  720 Monroe St Hoboken
# 720, Monroe Street, Hoboken, Hudson County, New Jersey, 07030, United States of America
# (40.7466675918367, -74.0378767142857)
# ['Sports', 'clubHillside,', 'NJ(201)', '224-7431Their', 'website', 'mentions', 'youth', 'sports']
# i9+Sports,+143+Coe+Ave,+Hillside,+NJ+07205
# ['i9 Sports', ' 143 Coe Ave', ' Hillside', ' NJ 07205']
#  143 Coe Ave Hillside
# 143, Coe Avenue, Hillside, Union County, New Jersey, 07205, United States
# (40.6910877663854, -74.2200071682221)
# ['Dance', 'schoolJersey', 'City,', 'NJ(201)', '377-0718Closed', '⋅', 'Opens', '3PM', 'Wed']
# Nimbus+Dance,+165+Newark+Ave,+Jersey+City,+NJ+07302
# ['Nimbus Dance', ' 165 Newark Ave', ' Jersey City', ' NJ 07302']
#  165 Newark Ave Jersey City
# Newark Avenue, Tonnelle Circle, Jersey City, Hudson County, New Jersey, 07306, United States
# (40.7389006, -74.0769497)
# ['Physical', 'fitness', 'programCherry', 'Hill,', 'NJ(844)', '454-3348Closed', '⋅', 'Opens', '9AM', 'Wed']
# Kid+Fit+NJ,+2040+Springdale+Rd,+Cherry+Hill,+NJ+08003
# ['Kid Fit NJ', ' 2040 Springdale Rd', ' Cherry Hill', ' NJ 08003']
#  2040 Springdale Rd Cherry Hill
# Cherry Hill, Springdale Road, Greenhills Historic District, Greenhills, Springfield Township, Hamilton County, Ohio, 45247, United States of America
# (39.26813625, -84.53199775)
# ['Preschool', '·', 'Closter', 'PlazaCloster,', 'NJ(201)', '983-1551']
# Kidville,+53+Vervalen+St,+Closter,+NJ+07624
# ['Kidville', ' 53 Vervalen St', ' Closter', ' NJ 07624']
#  53 Vervalen St Closter
# 53, Vervalen Street, Closter, Bergen County, New Jersey, 07624, United States
# (40.9704506177326, -73.9582628723433)
# ['Dance', 'schoolJersey', 'City,', 'NJ(201)', '792-1616Closed', '⋅', 'Opens', '9AM', 'Wed']
# Salsa+Fever+On+2+Dance+Academy,+83+Franklin+St,+Jersey+City,+NJ+07307
# ['Salsa Fever On 2 Dance Academy', ' 83 Franklin St', ' Jersey City', ' NJ 07307']
#  83 Franklin St Jersey City
# 83, Franklin Street, Jersey City, Hudson County, New Jersey, 07307, United States
# (40.7420044285714, -74.0483392857143)
# ['GymMaple', 'Shade', 'Township,', 'NJ(856)', '234-6445Closed', '⋅', 'Opens', '10AM', 'WedTheir', 'website', 'mentions', 'sport', 'classes']
# LittleSport,+120+E+Kings+Hwy+%23403,+Maple+Shade+Township,+NJ+08052
# ['LittleSport', ' 120 E Kings Hwy %23403', ' Maple Shade Township', ' NJ 08052']
#  120 E Kings Hwy %23403 Maple Shade Township
# 120, Kings Highway, Maple Shade Township, Burlington County, New Jersey, 08034, United States
# (39.9332787373737, -74.9894579090909)
# ['Yoga', 'studioJersey', 'City,', 'NJ(201)', '238-9903Closed', '⋅', 'Opens', '6:30AM', 'Wed']
# Sacred+Souls+Yoga+Studio,+2983+John+F.+Kennedy+Blvd+%23403,+Jersey+City,+NJ+07306
# ['Sacred Souls Yoga Studio', ' 2983 John F. Kennedy Blvd %23403', ' Jersey City', ' NJ 07306']
#  2983 John F. Kennedy Blvd %23403 Jersey City
# Jersey Farm, 2983, John F. Kennedy Boulevard, Indian Square, Jersey City, Hudson County, New Jersey, 07306, United States
# (40.7351129, -74.0634198)
# ['Gymnastics', 'centerSea', 'Girt,', 'NJ(732)', '292-9750Closed', '⋅', 'Opens', '9AM', 'Wed']
# The+Little+Gym+of+Sea+Girt,+2100+NJ-35+Unit+8,+Sea+Girt,+NJ+08750
# ['The Little Gym of Sea Girt', ' 2100 NJ-35 Unit 8', ' Sea Girt', ' NJ 08750']
#  2100 NJ-35 Unit 8 Sea Girt
# Cant Find the address
# ['Fitness', 'centerMorganville,', 'NJ(732)', '536-4141']
# Boston+Sports+Clubs,+34+Route+9+North,+Morganville,+NJ+07751
# ['Boston Sports Clubs', ' 34 Route 9 North', ' Morganville', ' NJ 07751']
#  34 Route 9 North Morganville
# Cant Find the address
# ['Dance', 'schoolJersey', 'City,', 'NJ(201)', '706-3025Closed', '⋅', 'Opens', '10:30AM', 'Wed']
# Next+Step+Broadway,+233+9th+St,+Jersey+City,+NJ+07302
# ['Next Step Broadway', ' 233 9th St', ' Jersey City', ' NJ 07302']
#  233 9th St Jersey City
# 9th Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.7287013, -74.048312)
# ['Swimming', 'school', '·', '24', 'Hour', 'FitnessParamus,', 'NJ(201)', '345-7558Closed', '⋅', 'Opens', '4PM', 'Wed']
# SafeSplash+Swim+School,+260+E+State+RT+4,+Paramus,+NJ+07652
# ['SafeSplash Swim School', ' 260 E State RT 4', ' Paramus', ' NJ 07652']
#  260 E State RT 4 Paramus
# Cant Find the address
# 4
# start=40
# start=60
# https://www.google.com/search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=60&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# 20
# ['Soccer', 'practiceJersey', 'City,', 'NJ(201)', '656-1156Closed', '⋅', 'Opens', '9AM', 'WedTheir', 'website', 'mentions', 'children', 'and', 'classes']
# The+Soccer+Learning+Center,+180+9th+St,+Jersey+City,+NJ+07302
# ['The Soccer Learning Center', ' 180 9th St', ' Jersey City', ' NJ 07302']
#  180 9th St Jersey City
# 180, 9th Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.7281241489362, -74.0412982340426)
# ['Taekwondo', 'schoolJersey', 'City,', 'NJ(201)', '656-9099Closed', '⋅', 'Opens', '10AM', 'Wed']
# Dong+Keun+Park+TaeKwonDo+Jersey+City.,+33+Journal+Square+Plaza,+Jersey+City,+NJ+07306
# ['Dong Keun Park TaeKwonDo Jersey City.', ' 33 Journal Square Plaza', ' Jersey City', ' NJ 07306']
#  33 Journal Square Plaza Jersey City
# Cant Find the address
# ['Personal', 'trainerJersey', 'City,', 'NJ(201)', '254-5406Closes', 'soon', '⋅', '11PM']
# jc+hiit+club,+911+Bergen+Ave,+Jersey+City,+NJ+07306
# ['jc hiit club', ' 911 Bergen Ave', ' Jersey City', ' NJ 07306']
#  911 Bergen Ave Jersey City
# 911, Bergen Avenue, Indian Square, Jersey City, Hudson County, New Jersey, 07306, United States of America
# (40.73033895, -74.0652690427822)
# ['Martial', 'arts', 'schoolJersey', 'City,', 'NJ(201)', '433-0515Closed', '⋅', 'Opens', '4PM', 'Wed']
# Team+Endurance+MMA%2F+Brazilian+JiuJitsu+%26+Kickboxing+Academy,+785+West+Side+Ave,+Jersey+City,+NJ+07306
# ['Team Endurance MMA%2F Brazilian JiuJitsu %26 Kickboxing Academy', ' 785 West Side Ave', ' Jersey City', ' NJ 07306']
#  785 West Side Ave Jersey City
# 785, West Side Avenue, Indian Square, Jersey City, Hudson County, New Jersey, 07306, United States
# (40.7271410572033, -74.0764406889831)
# ['Gymnastics', 'centerNewark,', 'NJ(908)', '546-3007Closed', '⋅', 'Opens', '3PM', 'Wed']
# Royal+Gymnastics,+33+Merchant+St,+Newark,+NJ+07105
# ['Royal Gymnastics', ' 33 Merchant St', ' Newark', ' NJ 07105']
#  33 Merchant St Newark
# 33, Merchant Street, The Ironbound, Newark, Essex County, New Jersey, 07105, United States
# (40.7284931818182, -74.1551207272727)
# ['Fencing', 'schoolJersey', 'City,', 'NJ(973)', '937-0987Closed', '⋅', 'Opens', '5:30PM', 'Wed']
# Cobra+Fencing+Club,+629+Grove+St,+Jersey+City,+NJ+07310
# ['Cobra Fencing Club', ' 629 Grove St', ' Jersey City', ' NJ 07310']
#  629 Grove St Jersey City
# 629, Grove Street, Newport, Jersey City, Hudson County, New Jersey, 07310, United States
# (40.7333431695371, -74.0409523692926)
# ['Martial', 'arts', 'schoolBayonne,', 'NJ(201)', '726-9741Closed', '⋅', 'Opens', '7:30AM', 'Wed"Kids', 'judo', 'classes', '@', 'SenshiTori', 'Mixed', 'Martial', 'Arts\xa0..."']
# Senshi+Tori+Mixed+Martial+Arts,+789+Broadway,+Bayonne,+NJ+07002
# ['Senshi Tori Mixed Martial Arts', ' 789 Broadway', ' Bayonne', ' NJ 07002']
#  789 Broadway Bayonne
# 789, Broadway, Bayonne, Hudson County, New Jersey, 07002, United States of America
# (40.6740997777778, -74.1097958888889)
# ['Martial', 'arts', 'schoolHoboken,', 'NJ(201)', '870-0719']
# Edge+Hoboken,+417+Newark+St,+Hoboken,+NJ+07030
# ['Edge Hoboken', ' 417 Newark St', ' Hoboken', ' NJ 07030']
#  417 Newark St Hoboken
# 417, Newark Street, Hoboken, Hudson County, New Jersey, 07030, United States of America
# (40.7369275612245, -74.0387619285714)
# ['Dance', 'schoolHoboken,', 'NJ(201)', '683-9100']
# Garden+Street+School+of+the+Performing+Arts,+1018+Washington+St+2nd+Floor,+Hoboken,+NJ+07030
# ['Garden Street School of the Performing Arts', ' 1018 Washington St 2nd Floor', ' Hoboken', ' NJ 07030']
#  1018 Washington St 2nd Floor Hoboken
# Cant Find the address
# ['Fitness', 'center', '·', 'Edgewater', 'City', 'PlaceEdgewater,', 'NJ(855)', '579-3287Closed', '⋅', 'Opens', '10:30AM', 'Wed']
# Sweat+NJ+KIDS,+42+City+Pl,+Edgewater,+NJ+07020
# ['Sweat NJ KIDS', ' 42 City Pl', ' Edgewater', ' NJ 07020']
#  42 City Pl Edgewater
# 42, City Place, Edgewater, Bergen County, New Jersey, 07020, United States
# (40.8075702819484, -73.9897644932853)
# ['GymCedar', 'Knolls,', 'NJ(973)', '206-1737Closed', '⋅', 'Opens', '5AM', 'Wed']
# Out+of+the+Box+Athletics+%7C+Cedar+Knolls+CrossFit,+45+Horse+Hill+Rd+Suite+105C,+Cedar+Knolls,+NJ+07927
# ['Out of the Box Athletics %7C Cedar Knolls CrossFit', ' 45 Horse Hill Rd Suite 105C', ' Cedar Knolls', ' NJ 07927']
#  45 Horse Hill Rd Suite 105C Cedar Knolls
# Cant Find the address
# ['Youth', 'organizationMadison,', 'NJ(973)', '822-9622Closes', 'soon', '⋅', '10:30PMTheir', 'website', 'mentions', 'youth', 'sports', 'and', 'classes']
# Madison+Area+YMCA,+111+Kings+Rd,+Madison,+NJ+07940
# ['Madison Area YMCA', ' 111 Kings Rd', ' Madison', ' NJ 07940']
#  111 Kings Rd Madison
# YMCA Family Center, 111, Kings Road, Madison, Morris County, New Jersey, 07940, United States of America
# (40.75362505, -74.412563970724)
# ['Boxing', 'gymJersey', 'City,', 'NJ(201)', '222-6565Closes', 'soon', '⋅', '11PM']
# World+Boxing+Gym,+29+Division+St,+Jersey+City,+NJ+07302
# ['World Boxing Gym', ' 29 Division St', ' Jersey City', ' NJ 07302']
#  29 Division St Jersey City
# 29, Division Street, Indian Square, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.7269242222222, -74.0520461111111)
# ['Gymnastics', 'centerBayonne,', 'NJ(201)', '455-8575Closed', '⋅', 'Opens', '4PM', 'Wed']
# Bridges+Gymnastics+Center,+56+New+Hook+Rd,+Bayonne,+NJ+07002
# ['Bridges Gymnastics Center', ' 56 New Hook Rd', ' Bayonne', ' NJ 07002']
#  56 New Hook Rd Bayonne
# Cant Find the address
# ['Youth', 'organizationHamburg,', 'NJ(973)', '209-9622Closed', '⋅', 'Opens', '5AM', 'Wed']
# Sussex+County+YMCA,+15+Wits+End+Dr,+Hamburg,+NJ+07419
# ['Sussex County YMCA', ' 15 Wits End Dr', ' Hamburg', ' NJ 07419']
#  15 Wits End Dr Hamburg
# Cant Find the address
# ['Yoga', 'studioJersey', 'City,', 'NJ(201)', '839-5242']
# Sattva+Yoga+Jersey+City,+523+Palisade+Ave,+Jersey+City,+NJ+07307
# ['Sattva Yoga Jersey City', ' 523 Palisade Ave', ' Jersey City', ' NJ 07307']
#  523 Palisade Ave Jersey City
# 523, Palisade Avenue, Jersey City, Hudson County, New Jersey, 07307, United States of America
# (40.7464102857143, -74.0428887142857)
# ['Gymnastics', 'centerWest', 'Windsor', 'Township,', 'NJ(609)', '799-7776Closed', '⋅', 'Opens', '9AM', 'Wed']
# Little+Gym+of+West+Windsor,+217+Clarksville+Rd,+West+Windsor+Township,+NJ+08550
# ['Little Gym of West Windsor', ' 217 Clarksville Rd', ' West Windsor Township', ' NJ 08550']
#  217 Clarksville Rd West Windsor Township
# 217, Clarksville Road, West Windsor Township, Mercer County, New Jersey, 08550, United States of America
# (40.2982674559781, -74.6433897027504)
# ['Gymnastics', 'centerBridgewater', 'Township,', 'NJ(908)', '526-9100Closed', '⋅', 'Opens', '9AM', 'Wed']
# The+Little+Gym+of+Bridgewater,+1335+Prince+Rodgers+Ave,+Bridgewater+Township,+NJ+08807
# ['The Little Gym of Bridgewater', ' 1335 Prince Rodgers Ave', ' Bridgewater Township', ' NJ 08807']
#  1335 Prince Rodgers Ave Bridgewater Township
# 1335, Prince Rodgers Avenue, Bridgewater Township, Somerset County, New Jersey, 08807, United States
# (40.5886903137246, -74.6118463302513)
# ['Yoga', 'studio']
# ['Sports', 'schoolNew', 'York,', 'NY(212)', '724-3278Closed', '⋅', 'Opens', '9AM', 'WedTheir', 'website', 'mentions', 'youth', 'sports', 'and', 'classes']
# Fastbreak+Sports,+1629+1st+Avenue,+New+York,+NY+10028
# ['Fastbreak Sports', ' 1629 1st Avenue', ' New York', ' NY 10028']
#  1629 1st Avenue New York
# 1629, 1st Avenue, Tribes Hill, Town of Mohawk, Montgomery County, New York, 12068, United States
# (42.9546209775398, -74.290946347522)
# 6
# start=60
# start=80
# https://www.google.com/search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=80&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# 20
# ['Martial', 'arts', 'schoolRobbinsville', 'Twp,', 'NJ(609)', '259-1519Closed', '⋅', 'Opens', '3PM', 'Wed']
# Everson's+Karate+%26+Cardio+Kickboxing,+2330+NJ-33+%23102,+Robbinsville+Twp,+NJ+08691
# ["Everson's Karate %26 Cardio Kickboxing", ' 2330 NJ-33 %23102', ' Robbinsville Twp', ' NJ 08691']
#  2330 NJ-33 %23102 Robbinsville Twp
# NJ 33, Robbinsville Township, Mercer County, New Jersey, 08691, United States of America
# (40.2187233, -74.6290611)
# ['Self', 'defense', 'schoolJersey', 'City,', 'NJ(908)', '432-2405']
# Arts+United+Capoeira,+54+Coles+St,+Jersey+City,+NJ+07302
# ['Arts United Capoeira', ' 54 Coles St', ' Jersey City', ' NJ 07302']
#  54 Coles St Jersey City
# 54, Coles Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.723628, -74.047331)
# ['Yoga', 'studioJersey', 'City,', 'NJ(201)', '993-1110Closed', '⋅', 'Opens', '6:45AM', 'Wed']
# Jivamukti+Yoga+Center+Jersey+City,+171+Newark+Ave+2nd+floor,+Jersey+City,+NJ+07302
# ['Jivamukti Yoga Center Jersey City', ' 171 Newark Ave 2nd floor', ' Jersey City', ' NJ 07302']
#  171 Newark Ave 2nd floor Jersey City
# Cant Find the address
# ['Fitness', 'centerJersey', 'City,', 'NJ(201)', '714-7600Closed', '⋅', 'Opens', '5:30AM', 'Wed']
# Hamilton+Health+%26+Fitness,+161+Erie+St,+Jersey+City,+NJ+07302
# ['Hamilton Health %26 Fitness', ' 161 Erie St', ' Jersey City', ' NJ 07302']
#  161 Erie St Jersey City
# 161, Erie Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.727359, -74.043555)
# ['Martial', 'arts', 'schoolHackensack,', 'NJ(201)', '221-6546Closed', '⋅', 'Opens', '10AM', 'Wed']
# Poise+Martial+Arts+of+Hackensack,+123+Main+St,+Hackensack,+NJ+07601
# ['Poise Martial Arts of Hackensack', ' 123 Main St', ' Hackensack', ' NJ 07601']
#  123 Main St Hackensack
# 123, Main Street, Hackensack, Bergen County, New Jersey, 07601, United States
# (40.882028184209, -74.0437089023774)
# ['Gymnastics', 'centerJersey', 'City,', 'NJ(201)', '222-6209Closed', '⋅', 'Opens', '10:30AM', 'Wed']
# The+Little+Gym+of+Jersey+City,+380+Newark+Ave+Units+101+%26+102,+Jersey+City,+NJ+07302
# ['The Little Gym of Jersey City', ' 380 Newark Ave Units 101 %26 102', ' Jersey City', ' NJ 07302']
#  380 Newark Ave Units 101 %26 102 Jersey City
# Cant Find the address
# ['Martial', 'arts', 'school', '·', 'Old', 'Colony', 'SquareJersey', 'City,', 'NJ(201)', '706-2201Closed', '⋅', 'Opens', '2PM', 'Wed"But', 'kids', 'who', 'learn', 'and', 'think', 'differently', 'can', 'have', 'a', 'hard', 'time', 'finding', 'a', 'sport', 'that', 'suits', '..."']
# Family+Fitness+Karate+%26+Kickboxing+-+Downtown+Jersey+City,+263+Monmouth+St,+Jersey+City,+NJ+07302
# ['Family Fitness Karate %26 Kickboxing - Downtown Jersey City', ' 263 Monmouth St', ' Jersey City', ' NJ 07302']
#  263 Monmouth St Jersey City
# 263, Monmouth Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.7186966734694, -74.0514296122449)
# ['Self', 'defense', 'schoolJersey', 'City,', 'NJ(201)', '792-0797']
# Jang+Star+Taekwondo+School,+299+Central+Ave,+Jersey+City,+NJ+07307
# ['Jang Star Taekwondo School', ' 299 Central Ave', ' Jersey City', ' NJ 07307']
#  299 Central Ave Jersey City
# 299, Central Avenue, Jersey City, Hudson County, New Jersey, 07307, United States of America
# (40.7452237142857, -74.0499904285714)
# ['Gymnastics', 'center', '·', 'Marlton', 'Crossing', 'Shopping', 'CenterMarlton,', 'NJ(856)', '810-0010Closed', '⋅', 'Opens', '9AM', 'WedTheir', 'website', 'mentions', 'kids', 'and', 'classes']
# Little+Gym,+117+NJ-73,+Marlton,+NJ+08053
# ['Little Gym', ' 117 NJ-73', ' Marlton', ' NJ 08053']
#  117 NJ-73 Marlton
# 117, State Route 73, Greentree Square, Evesham Township, Burlington County, New Jersey, 08053, United States of America
# (39.8970623222454, -74.9300854585066)
# ['GymJersey', 'City,', 'NJ(201)', '743-9443Closed', '⋅', 'Opens', '5:30AM', 'Wed']
# JCF+Boot+Camp,+39+Erie+St,+Jersey+City,+NJ+07302
# ['JCF Boot Camp', ' 39 Erie St', ' Jersey City', ' NJ 07302']
#  39 Erie St Jersey City
# 39, Erie Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.722633, -74.044252)
# ['GymHoboken,', 'NJ(201)', '222-0802Closed', '⋅', 'Opens', '6AM', 'Wed']
# Work+it+Out,+603+Willow+Ave,+Hoboken,+NJ+07030
# ['Work it Out', ' 603 Willow Ave', ' Hoboken', ' NJ 07030']
#  603 Willow Ave Hoboken
# 603, Willow Avenue, Hoboken, Hudson County, New Jersey, 07030, United States of America
# (40.74426565, -74.0324207021526)
# ['Sports', 'complexChatham,', 'NJ(973)', '855-3111Closed', '⋅', 'Opens', '6AM', 'Wed']
# Centercourt+Athletic+Club+of+Chatham,+222+N+Passaic+Ave,+Chatham,+NJ+07928
# ['Centercourt Athletic Club of Chatham', ' 222 N Passaic Ave', ' Chatham', ' NJ 07928']
#  222 N Passaic Ave Chatham
# 222, North Passaic Avenue, Chatham, Morris County, New Jersey, 07928, United States of America
# (40.7503684081633, -74.373065877551)
# ['GymHoboken,', 'NJ(201)', '222-2582Closes', 'soon', '⋅', '11PM']
# Skyclub+Fitness+%26+Spa,+125+Marshall+St+7th+Floor,+Hoboken,+NJ+07030
# ['Skyclub Fitness %26 Spa', ' 125 Marshall St 7th Floor', ' Hoboken', ' NJ 07030']
#  125 Marshall St 7th Floor Hoboken
# Cant Find the address
# ['GymJersey', 'City,', 'NJ(201)', '204-4360Closes', 'soon', '⋅', '11PM']
# Blink+Fitness,+35+Journal+Square+Plaza,+Jersey+City,+NJ+07306
# ['Blink Fitness', ' 35 Journal Square Plaza', ' Jersey City', ' NJ 07306']
#  35 Journal Square Plaza Jersey City
# Cant Find the address
# ['Swimming', 'schoolCherry', 'Hill,', 'NJ(856)', '751-5437Closed', '⋅', 'Opens', '9AM', 'Wed']
# KIDS+FIRST+Swim+School+-+Cherry+Hill,+1900+Greentree+Rd,+Cherry+Hill,+NJ+08003
# ['KIDS FIRST Swim School - Cherry Hill', ' 1900 Greentree Rd', ' Cherry Hill', ' NJ 08003']
#  1900 Greentree Rd Cherry Hill
# Cant Find the address
# ['Fencing', 'schoolMaplewood,', 'NJ(973)', '762-6363Closed', '⋅', 'Opens', '4PM', 'Wed']
# New+Jersey+Fencing+Alliance,+50+Burnett+Ave,+Maplewood,+NJ+07040
# ['New Jersey Fencing Alliance', ' 50 Burnett Ave', ' Maplewood', ' NJ 07040']
#  50 Burnett Ave Maplewood
# 50, Burnett Avenue, Maplewood, Essex County, New Jersey, 07040, United States of America
# (40.720866, -74.2591200769231)
# ['Martial', 'arts', 'schoolHasbrouck', 'Heights,', 'NJ(201)', '754-4408Closed', '⋅', 'Opens', '9AM', 'Wed']
# Sidekick+Martial+Arts+%26+Fitness,+155+NJ-17,+Hasbrouck+Heights,+NJ+07604
# ['Sidekick Martial Arts %26 Fitness', ' 155 NJ-17', ' Hasbrouck Heights', ' NJ 07604']
#  155 NJ-17 Hasbrouck Heights
# 155, NJ 17, Hasbrouck Heights, Bergen County, New Jersey, 07604, United States
# (40.8565016724401, -74.0702062121609)
# ['Swimming', 'schoolJersey', 'City,', 'NJ(201)', '208-4089Closed', '⋅', 'Opens', '6PM', 'Wed']
# Swim+Stars,+870+Montgomery+St,+Jersey+City,+NJ+07306
# ['Swim Stars', ' 870 Montgomery St', ' Jersey City', ' NJ 07306']
#  870 Montgomery St Jersey City
# 870, Montgomery Street, Indian Square, Jersey City, Hudson County, New Jersey, 07306, United States
# (40.7271943445021, -74.0729820301264)
# ['Public', 'swimming', 'poolGarfield,', 'NJ(973)', '928-2970Closed', '⋅', 'Opens', '5:30AM', 'WedTheir', 'website', 'mentions', 'youth', 'sports', 'and', 'classes']
# Garfield+YMCA,+33+Outwater+Ln,+Garfield,+NJ+07026
# ['Garfield YMCA', ' 33 Outwater Ln', ' Garfield', ' NJ 07026']
#  33 Outwater Ln Garfield
# 33, Outwater Lane, Garfield, Bergen County, New Jersey, 07026, United States
# (40.880455, -74.1174943333333)
# ['Dance', 'schoolParamus,', 'NJ(201)', '819-7989']
# DDA+Dance+Academy,+40+Eisenhower+Dr+%23102,+Paramus,+NJ+07652
# ['DDA Dance Academy', ' 40 Eisenhower Dr %23102', ' Paramus', ' NJ 07652']
#  40 Eisenhower Dr %23102 Paramus
# 40, Eisenhower Drive, Arcola, Paramus, Bergen County, New Jersey, 07652, United States
# (40.9300192812892, -74.0778345166592)
# 8
# start=80
# start=100
# https://www.google.com/search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=100&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# 20
# ['GymWest', 'New', 'York,', 'NJ(201)', '546-1010Closed', '⋅', 'Opens', '6AM', 'Wed']
# CKO+Kickboxing,+4914+John+F.+Kennedy+Blvd,+West+New+York,+NJ+07093
# ['CKO Kickboxing', ' 4914 John F. Kennedy Blvd', ' West New York', ' NJ 07093']
#  4914 John F. Kennedy Blvd West New York
# John F. Kennedy Boulevard, West New York, Hudson County, New Jersey, 07047, United States
# (40.7894897, -74.0233961)
# ['Martial', 'arts', 'schoolNewark,', 'NJ(973)', '420-2982Closed', '⋅', 'Opens', '10AM', 'Wed']
# The+Brazilian+Cultural+Center+of+Newark,+29+Backus+St,+Newark,+NJ+07105
# ['The Brazilian Cultural Center of Newark', ' 29 Backus St', ' Newark', ' NJ 07105']
#  29 Backus St Newark
# 29, Backus Street, The Ironbound, Newark, Essex County, New Jersey, 07105, United States
# (40.7195068571429, -74.1556512857143)
# ['Gymnastics', 'centerWaldwick,', 'NJ(201)', '445-4444']
# The+Little+Gym+of+Waldwick,+28+Franklin+Turnpike,+Waldwick,+NJ+07463
# ['The Little Gym of Waldwick', ' 28 Franklin Turnpike', ' Waldwick', ' NJ 07463']
#  28 Franklin Turnpike Waldwick
# The Little Gym, 28, Franklin Turnpike, Waldwick, Bergen County, New Jersey, 07463, United States of America
# (41.0094741, -74.1197207)
# ['Non-profit', 'organizationMontclair,', 'NJ(973)', '744-3400Closed', '⋅', 'Opens', '5AM', 'Wed']
# YMCA+of+Montclair,+25+Park+St,+Montclair,+NJ+07042
# ['YMCA of Montclair', ' 25 Park St', ' Montclair', ' NJ 07042']
#  25 Park St Montclair
# 25, Park Street, Montclair, Essex County, New Jersey, 07042, United States of America
# (40.8159507142857, -74.2182045714286)
# ['GymHoboken,', 'NJ(201)', '332-4269Closed', '⋅', 'Opens', '6AM', 'Wed']
# UFC+GYM+Hoboken,+316+Sinatra+Dr,+Hoboken,+NJ+07030
# ['UFC GYM Hoboken', ' 316 Sinatra Dr', ' Hoboken', ' NJ 07030']
#  316 Sinatra Dr Hoboken
# Sinatra Drive, Hoboken, Hudson County, New Jersey, 07030-5774, United States of America
# (40.744831, -74.022959)
# ['Martial', 'arts', 'schoolNewark,', 'NJ(862)', '305-0369Closed', '⋅', 'Opens', '4PM', 'Wed']
# Team+Raposa+Taekwondo+%2F+Boxing+%2F+Kickboxing+%2F+Fitness,+86+Monroe+St,+Newark,+NJ+07105
# ['Team Raposa Taekwondo %2F Boxing %2F Kickboxing %2F Fitness', ' 86 Monroe St', ' Newark', ' NJ 07105']
#  86 Monroe St Newark
# 86, Monroe Street, The Ironbound, Newark, Essex County, New Jersey, 07105, United States of America
# (40.73007832, -74.15921312)
# ['Self', 'defense', 'schoolHarrison,', 'NJ(973)', '445-7796Closed', '⋅', 'Opens', '9:30AM', 'Wed']
# Cutting+Edge+Brazilian+Jiu-Jitsu+Academy,+756+Harrison+Ave,+Harrison,+NJ+07029
# ['Cutting Edge Brazilian Jiu-Jitsu Academy', ' 756 Harrison Ave', ' Harrison', ' NJ 07029']
#  756 Harrison Ave Harrison
# 756, Harrison Avenue, Harrison, Hudson County, New Jersey, 07032, United States
# (40.74785165, -74.148351572432)
# ['Non-profit', 'organizationEast', 'Rutherford,', 'NJ(201)', '955-5300Closed', '⋅', 'Opens', '5AM', 'Wed']
# Meadowlands+Area+YMCA,+390+Murray+Hill+Pkwy,+East+Rutherford,+NJ+07073
# ['Meadowlands Area YMCA', ' 390 Murray Hill Pkwy', ' East Rutherford', ' NJ 07073']
#  390 Murray Hill Pkwy East Rutherford
# 390, Murray Hill Parkway, East Rutherford, Bergen County, New Jersey, 07073, United States of America
# (40.8207188218484, -74.090879900841)
# ['Sports', 'schoolWhitehouse', 'Station,', 'NJ(732)', '563-2520Closed', '⋅', 'Opens', '8:30AM', 'Wed']
# US+Sports+Institute,+4+Somerset+St,+Whitehouse+Station,+NJ+08889
# ['US Sports Institute', ' 4 Somerset St', ' Whitehouse Station', ' NJ 08889']
#  4 Somerset St Whitehouse Station
# 4, Somerset Street, Readington Township, Hunterdon County, New Jersey, 08889, United States
# (40.6160045725981, -74.7697447177942)
# ['Physical', 'fitness', 'programBelleville,', 'NJ(862)', '686-1766Closed', '⋅', 'Opens', '5PM', 'Wed']
# Zumba+in+NJ,+390+Union+Ave,+Belleville,+NJ+07109
# ['Zumba in NJ', ' 390 Union Ave', ' Belleville', ' NJ 07109']
#  390 Union Ave Belleville
# 390, Union Avenue, Belleville, Saint Clair County, Illinois, 62220, United States
# (38.5057509756098, -89.9966294390244)
# ['Gymnastics', 'centerParlin,', 'NJ(732)', '238-6900Closed', '⋅', 'Opens', '9AM', 'Wed']
# Head+Over+Heels+Gymnastics,+Dance+%26+Cheer+Center,+287+Cheesequake+Rd,+Parlin,+NJ+08859
# ['Head Over Heels Gymnastics', ' Dance %26 Cheer Center', ' 287 Cheesequake Rd', ' Parlin', ' NJ 08859']
# ['', 'NJ', '08859']
#  287 Cheesequake Rd Parlin
# Cheesequake Road, Townelake at Sayreville, Sayreville, Middlesex County, New Jersey, 08872, United States
# (40.459809, -74.34053)
# ['Youth', 'organization(201)', '375-7406Closed', '⋅', 'Opens', '8AM', 'Wed']
# ['Rock', 'climbing', 'gymHoboken,', 'NJ(201)', '740-1423Closes', 'soon', '⋅', '11PM']
# The+Gravity+Vault+Hoboken,+NJ,+1423+Clinton+St,+Hoboken,+NJ+07030
# ['The Gravity Vault Hoboken', ' NJ', ' 1423 Clinton St', ' Hoboken', ' NJ 07030']
# ['', 'NJ', '07030']
#  1423 Clinton St Hoboken
# The Gravity Vault Hoboken, 1423, Clinton Street, Hoboken, Hudson County, New Jersey, 07030, United States
# (40.75485655, -74.030067520011)
# ['Yoga', 'studioHoboken,', 'NJ(201)', '792-5254Closed', '⋅', 'Opens', '6AM', 'Wed']
# Asana+Soul+Practice+-+Hoboken,+411+Jefferson+St,+Hoboken,+NJ+07030
# ['Asana Soul Practice - Hoboken', ' 411 Jefferson St', ' Hoboken', ' NJ 07030']
#  411 Jefferson St Hoboken
# 411, Jefferson Street, Hoboken, Hudson County, New Jersey, 07030, United States of America
# (40.7426929387755, -74.0369158571429)
# ['Corporate', 'officeNewark,', 'NJ(973)', '624-8900Closed', '⋅', 'Opens', '5:30AM', 'Wed']
# YM%2FWCA+Newark+%26+Vicinity,+600+Broad+St,+Newark,+NJ+07102
# ['YM%2FWCA Newark %26 Vicinity', ' 600 Broad St', ' Newark', ' NJ 07102']
#  600 Broad St Newark
# Broad Street, Teachers Village, Newark, Essex County, New Jersey, 07114, United States
# (40.7225345, -74.1798361)
# ['Swimming', 'schoolDeptford', 'Township,', 'NJ(856)', '227-7284']
# KIDS+FIRST+Swim+School+-+Deptford,+1500+Almonesson+Rd,+Deptford+Township,+NJ+08096
# ['KIDS FIRST Swim School - Deptford', ' 1500 Almonesson Rd', ' Deptford Township', ' NJ 08096']
#  1500 Almonesson Rd Deptford Township
# Cant Find the address
# ['Boxing', 'clubNorth', 'Bergen,', 'NJ(201)', '430-8901Closed', '⋅', 'Opens', '10AM', 'Wed']
# State+of+Fitness+Boxing+Club,+508+73rd+St,+North+Bergen,+NJ+07047
# ['State of Fitness Boxing Club', ' 508 73rd St', ' North Bergen', ' NJ 07047']
#  508 73rd St North Bergen
# 508, 73rd Street, North Bergen, Hudson County, New Jersey, 07047, United States
# (40.798063885906, -74.0096585771812)
# ['Self', 'defense', 'schoolJersey', 'City,', 'NJ(201)', '201-0370']
# CKO+Kickboxing,+Jersey+City,+150+Bay+St,+Jersey+City,+NJ+07302
# ['CKO Kickboxing', ' Jersey City', ' 150 Bay St', ' Jersey City', ' NJ 07302']
# ['', 'NJ', '07302']
#  150 Bay St Jersey City
# Departed Soles Brewing Company, 150, Bay Street, Newport, Jersey City, Hudson County, New Jersey, 07302, United States of America
# (40.7208296, -74.0400315)
# ['Ballet', 'school', '·', 'Brunswick', 'Center', 'CommunityJersey', 'City,', 'NJ(551)', '655-9875']
# Jersey+City+Ballet,+189+Brunswick+St+2nd+Floor,+Jersey+City,+NJ+07302
# ['Jersey City Ballet', ' 189 Brunswick St 2nd Floor', ' Jersey City', ' NJ 07302']
#  189 Brunswick St 2nd Floor Jersey City
# Cant Find the address
# ['Fitness', 'center', '·', 'Edgewater', 'City', 'PlaceEdgewater,', 'NJ(201)', '313-3300Closes', 'soon', '⋅', '11PM']
# Tilton+Fitness+Edgewater,+42+City+Pl,+Edgewater,+NJ+07020
# ['Tilton Fitness Edgewater', ' 42 City Pl', ' Edgewater', ' NJ 07020']
#  42 City Pl Edgewater
# 42, City Place, Edgewater, Bergen County, New Jersey, 07020, United States
# (40.8075702819484, -73.9897644932853)
# 10
# start=100
# start=120
# https://www.google.com/search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=120&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# 1
# ['Gymnastics', 'center5501', 'NJ-42(856)', '228-2818']
# Little+Gym+Of+Washington+Township,+5501+NJ-42,+Blackwood,+NJ+08012
# ['Little Gym Of Washington Township', ' 5501 NJ-42', ' Blackwood', ' NJ 08012']
#  5501 NJ-42 Blackwood
# Blackwood, North-South Freeway, Gloucester Township, Camden County, New Jersey, 08029, United States
# (39.799232, -75.0641698821179)
# 12
# start=120
# start=140
# https://www.google.com/search?q=kids+sports+classes+new+jersey&rlz=1C1CHBF_enUS853US853&sz=0&tbm=lcl&ei=6OfdXZDVLu2Oggfzwr34BQ&start=140&sa=N&ved=0ahUKEwiQ6Z2ftInmAhVth-AKHXNhD18Q8tMDCPwB
# 0

# %%
df.to_excel("outputSports.xlsx") 
df
# Out:
#                                  Name Reviews       phoneNo  \
# 0                            Kidville    None             9
# 1          The Little Gym of Aberdeen    None    7327720060
# 2         Shim's Martial Arts Academy    None             4
# 3                 The Kennedy Dancers    None             2
# 4             Bayonne Karate For Kids    None             3
# ..                                ...     ...           ...
# 76       State of Fitness Boxing Club    None            10
# 77        CKO Kickboxing, Jersey City    None    2012010370
# 78                 Jersey City Ballet    None    5516559875
# 79           Tilton Fitness Edgewater    None            11
# 80  Little Gym Of Washington Township    None  428562282818
#
#                         Address           City State Zipcode  \
# 0                 516 Valley Rd      Montclair    NJ   07043
# 1            1121 NJ-34 Suite O        Matawan    NJ   07747
# 2              1115 E Jersey St      Elizabeth    NJ   07201
# 3                79 Central Ave    Jersey City    NJ   07306
# 4                  434 Broadway        Bayonne    NJ   07002
# ..                          ...            ...   ...     ...
# 76                  508 73rd St   North Bergen    NJ   07047
# 77                   150 Bay St    Jersey City    NJ   07302
# 78   189 Brunswick St 2nd Floor    Jersey City    NJ   07302
# 79                   42 City Pl      Edgewater    NJ   07020
# 80                   5501 NJ-42      Blackwood    NJ   08012
#
#                                  Location
# 0                 [40.837221, -74.206941]
# 1                                     NaN
# 2   [40.6645016373729, -74.2119637176314]
# 3                 [40.737391, -74.055331]
# 4               [40.6617075, -74.1200142]
# ..                                    ...
# 76   [40.798063885906, -74.0096585771812]
# 77              [40.7208296, -74.0400315]
# 78                                    NaN
# 79  [40.8075702819484, -73.9897644932853]
# 80         [39.799232, -75.0641698821179]
#
# [81 rows x 8 columns]
