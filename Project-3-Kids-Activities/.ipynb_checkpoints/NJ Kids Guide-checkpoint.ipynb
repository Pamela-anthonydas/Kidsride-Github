# %%
from splinter import Browser
from bs4 import BeautifulSoup 
import time
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'http://www.kidsguidenj.com/music_dance/music_dance.html'
browser.visit(url)

# %%
Music_Dance_Data =[]
 

html = browser.html
soup = BeautifulSoup(html, 'html.parser')

print
Music_Dance_Data= soup.find_all("div", id ="maincontent")
print(Music_Dance_Data)
    #time.sleep(7)
# Out:
# [<div id="maincontent" style="height: auto !important;"><!-- InstanceBeginEditable name="bannerad" -->
# <div id="bannerad">
# <a href="../camps/camps.html"><img alt="nj kids summer camps guide" height="70" src="../images/CampGuide-1.gif" width="160"/></a><a href="../schools/schools.html"><img alt="nj private schools, preschools, tutors, education guide" height="70" src="../images/EducationGuide-1.gif" width="160"/></a><a href="../party_planner/parties.html"><img alt="nj kids parties, birthday party and special event entertainers in new jersey" height="70" src="../images/PartyPlanner-1.gif" width="160"/></a>
# </div>
# <!-- InstanceEndEditable -->
# <!-- InstanceBeginEditable name="MainContent" --><img alt="NJ Music &amp; Dance Performances for Kids, Teens &amp; Adults in New Jersey" height="40" src="music_dance.gif" width="250"/>
# <div class="introlisting">
# <p><span class="subtext"><strong>the arts</strong><br/>
# ...

# %%
md_Tittle = []
md_Link = []
md_Desc = []

md_Data =  soup.find_all('p')

#for a in soup.find_all('a', href=True):
#    print(  a['href'])
print(len(md_Data))   

md_Tittle = soup.find_all("a", target= "_blank", class_="sublink")
    
print((md_Tittle))
# Out:
# 83
# ...

# %%
soup.find("div", class_ ="sublink").next_sibling
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-92cc734a8adb> in <module>
# ----> 1 soup.find("div", class_ ="sublink").next_sibling
#
# AttributeError: 'NoneType' object has no attribute 'next_sibling'

# %%
soup.find("a", class_ ="sublink").next_sibling
